# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("laptop-data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns =[ 'Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.displot(df['Price'])

# %%
df['Company'].value_counts().plot(kind='bar',color = 'orange')
# Out:
# <Axes: xlabel='Company'>

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['Company'],y=df['Price'],color = 'green')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(3)
# Out:
#     Company  TypeName  Inches   ScreenResolution                          Cpu  \
# 982  Lenovo  Notebook    15.6  Full HD 1920x1080  AMD A12-Series 9720P 3.6GHz
# 404     MSI    Gaming    17.3  Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 228    Asus  Notebook    17.3  Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
#
#      Ram                  Memory                      Gpu       OpSys  Weight  \
# 982    6               256GB SSD           AMD Radeon 530  Windows 10    2.20
# 404   16    256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10    2.80
# 228    8  256GB SSD +  500GB HDD  Nvidia GeForce GTX 950M  Windows 10    2.69
#
#          Price  Touchscreen
# 982   29250.72            0
# 404  119826.72            0
# 228   47472.48            0

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'],color = 'yellow')
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df.head(4)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1

# %%
df['Ips'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
df['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
sns.barplot(x=df['Touchscreen'], y=df['Price'],color = 'yellow')
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 797     Dell  Notebook    15.6                     1366x768
# 1237    Dell  Notebook    15.6                     1366x768
# 463   Lenovo  Notebook    14.0  IPS Panel Full HD 1920x1080
# 193   Lenovo  Notebook    17.3                     1600x900
# 355     Dell  Notebook    15.6            Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 797   Intel Core i5 7200U 2.5GHz    8             128GB SSD
# 1237  Intel Core i5 6200U 2.3GHz    4             500GB HDD
# 463   Intel Core i7 7500U 2.7GHz    8             512GB SSD
# 193   Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 355   Intel Core i7 8550U 1.8GHz    8  128GB SSD +  2TB HDD
#
#                         Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# 797   Intel HD Graphics 620  Windows 10    1.95  43156.800            0    0
# 1237  Intel HD Graphics 520   Windows 7    2.24  39267.360            0    0
# 463      AMD Radeon R7 M460       No OS    1.50  42570.720            0    1
# 193    Nvidia GeForce MX150       No OS    2.80  37189.440            0    0
# 355          AMD Radeon 530  Windows 10    2.02  51729.552            0    0
#
#                        X_res Y_res
# 797                     1366   768
# 1237                    1366   768
# 463   IPS Panel Full HD 1920  1080
# 193                     1600   900
# 355             Full HD 1920  1080

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['X_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# memory usage: 142.6+ KB

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000            0    0
#
#    X_res  Y_res         ppi
# 0   2560   2560  272.209528
# 1   1440   1440  153.117859
# 2   1920   1920  174.057054

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head(5)
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# 0  272.209528  Intel Core i5
# 1  153.117859  Intel Core i5
# 2  174.057054  Intel Core i5
# 3  264.476303  Intel Core i7
# 4  272.209528  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(5)
# Out:
#      Company            TypeName                           ScreenResolution  \
# 892  Samsung           Ultrabook                          Full HD 1920x1080
# 469   Lenovo           Ultrabook               IPS Panel Quad HD+ 2560x1440
# 596   Lenovo  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 180     Dell            Notebook                          Full HD 1920x1080
# 612     Dell            Notebook                                   1366x768
#
#                             Cpu  Ram                Memory  \
# 892  Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 469  Intel Core i7 6600U 2.6GHz   12             256GB SSD
# 596  Intel Core i7 7500U 2.7GHz    8             512GB SSD
# 180  Intel Core i7 8550U 1.8GHz   16  256GB SSD +  2TB HDD
# 612  Intel Core i3 6006U 2.0GHz    4               1TB HDD
#
#                        Gpu       OpSys  Weight       Price  Touchscreen  Ips  \
# 892  Intel HD Graphics 620  Windows 10    1.17   90522.720            0    0
# 469  Intel HD Graphics 520  Windows 10    1.40   98994.240            0    1
# 596  Intel HD Graphics 620  Windows 10    1.37  107892.000            1    1
# 180         AMD Radeon 530       Linux    2.02   55890.720            0    0
# 612  Intel HD Graphics 520       Linux    2.18   23650.992            0    0
#
#             ppi       Cpu Name      Cpu brand
# 892  181.019336  Intel Core i7  Intel Core i7
# 469  258.599051  Intel Core i7  Intel Core i7
# 596  204.157146  Intel Core i7  Intel Core i7
# 180  174.057054  Intel Core i7  Intel Core i7
# 612  123.834341  Intel Core i3  Intel Core i3

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head(4)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
#
#          Price  Touchscreen  Ips         ppi      Cpu brand
# 0   71378.6832            0    1  272.209528  Intel Core i5
# 1   47895.5232            0    0  153.117859  Intel Core i5
# 2   30636.0000            0    0  174.057054  Intel Core i5
# 3  135195.3360            0    1  264.476303  Intel Core i7

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'],color = 'green')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# 1. Convert Memory to string & clean decimals
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)

# 2. Normalize units (TB → GB)
df['Memory'] = df['Memory'].str.replace('TB', '000', regex=False)
df['Memory'] = df['Memory'].str.replace('GB', '', regex=False)

# 3. Split into two storage layers (if exists)
new = df['Memory'].str.split('+', n=1, expand=True)

df['first'] = new[0].str.strip()
df['second'] = new[1].fillna('0')

# 4. Detect storage types (Layer 1)
df['Layer1HDD'] = df['first'].str.contains('HDD', case=False, na=False).astype(int)
df['Layer1SSD'] = df['first'].str.contains('SSD', case=False, na=False).astype(int)
df['Layer1Hybrid'] = df['first'].str.contains('Hybrid', case=False, na=False).astype(int)
df['Layer1Flash_Storage'] = df['first'].str.contains('Flash Storage', case=False, na=False).astype(int)

# 5. Detect storage types (Layer 2)
df['Layer2HDD'] = df['second'].str.contains('HDD', case=False, na=False).astype(int)
df['Layer2SSD'] = df['second'].str.contains('SSD', case=False, na=False).astype(int)
df['Layer2Hybrid'] = df['second'].str.contains('Hybrid', case=False, na=False).astype(int)
df['Layer2Flash_Storage'] = df['second'].str.contains('Flash Storage', case=False, na=False).astype(int)

# 6. Extract numeric values safely
df['first'] = df['first'].str.replace(r'\D', '', regex=True)
df['second'] = df['second'].str.replace(r'\D', '', regex=True)

df['first'] = pd.to_numeric(df['first'], errors='coerce').fillna(0).astype(int)
df['second'] = pd.to_numeric(df['second'], errors='coerce').fillna(0).astype(int)

# 7. Final storage calculation (in GB)
df['HDD'] = df['first'] * df['Layer1HDD'] + df['second'] * df['Layer2HDD']
df['SSD'] = df['first'] * df['Layer1SSD'] + df['second'] * df['Layer2SSD']
df['Hybrid'] = df['first'] * df['Layer1Hybrid'] + df['second'] * df['Layer2Hybrid']
df['Flash_Storage'] = (
    df['first'] * df['Layer1Flash_Storage'] +
    df['second'] * df['Layer2Flash_Storage']
)

# 8. Drop temporary columns
df.drop(columns=[
    'first', 'second',
    'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)

# %%
df.sample(5)
# Out:
#       Company     TypeName                    ScreenResolution  Ram    Memory  \
# 548        HP     Notebook                   Full HD 1920x1080    4   500 HDD
# 736        HP  Workstation                   Full HD 1920x1080   16   256 SSD
# 270     Apple    Ultrabook  IPS Panel Retina Display 2560x1600    8   512 SSD
# 143   Toshiba     Notebook                            1366x768    4   500 HDD
# 1273       HP     Notebook                            1366x768    6  1000 HDD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen  \
# 548     Intel HD Graphics 520  Windows 10    1.86   21152.160            0
# 736       Nvidia Quadro M2200  Windows 10    2.60  128884.320            0
# 270   Intel Iris Graphics 550       macOS    1.37  104370.192            0
# 143     Intel HD Graphics 520  Windows 10    2.10   32074.560            0
# 1273       AMD Radeon R5 M330  Windows 10    2.19   40705.920            0
#
#       Ips         ppi      Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# 548     0  174.057054  Intel Core i3   500    0       0              0
# 736     0  174.057054  Intel Core i7     0  256       0              0
# 270     1  272.209528  Intel Core i5     0  512       0              0
# 143     0  123.834341  Intel Core i5   500    0       0              0
# 1273    0  123.834341  Intel Core i7  1000    0       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head(4)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
#
#           ppi      Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 0  272.209528  Intel Core i5    0  128       0              0
# 1  153.117859  Intel Core i5    0    0       0            128
# 2  174.057054  Intel Core i5    0  256       0              0
# 3  264.476303  Intel Core i7    0  512       0              0

# %%
df.drop(columns =['Hybrid','Flash_Storage'],inplace = True)

# %%
df.head(5)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD
# 0  272.209528  Intel Core i5    0  128
# 1  153.117859  Intel Core i5    0    0
# 2  174.057054  Intel Core i5    0  256
# 3  264.476303  Intel Core i7    0  512
# 4  272.209528  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cate_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 10 S' or inp == 'Windows 7':
        return 'Windows'
    elif inp == 'macOS' or inp == 'mac OS X' :
        return 'MacOs'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cate_os)

# %%
df.head(3)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  OpSys  Weight  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8  macOS    1.37
# 1   Apple  Ultrabook                            1440x900    8  macOS    1.34
# 2      HP   Notebook                   Full HD 1920x1080    8  No OS    1.86
#
#         Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0  71378.6832            0    1  272.209528  Intel Core i5    0  128
# 1  47895.5232            0    0  153.117859  Intel Core i5    0    0
# 2  30636.0000            0    0  174.057054  Intel Core i5    0  256
#
#   Gpu brand                  os
# 0     Intel               MacOs
# 1     Intel               MacOs
# 2     Intel  Others/No OS/Linux

# %%
df.drop(columns = ['OpSys'], inplace = True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\supri\AppData\Local\Temp\ipykernel_24100\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\supri\AppData\Local\Temp\ipykernel_24100\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
#       Ram  Weight  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 0       8    1.37            0    1  272.209528          Intel Core i5     0
# 1       8    1.34            0    0  153.117859          Intel Core i5     0
# 2       8    1.86            0    0  174.057054          Intel Core i5     0
# 3      16    1.83            0    1  264.476303          Intel Core i7     0
# 4       8    1.37            0    1  272.209528          Intel Core i5     0
# ...   ...     ...          ...  ...         ...                    ...   ...
# 1298    4    1.80            1    1  193.949289          Intel Core i7     0
# 1299   16    1.30            1    1  340.261910          Intel Core i7     0
# 1300    2    1.50            0    0  137.986838  Other Intel Processor     0
# 1301    6    2.19            0    0  123.834341          Intel Core i7  1000
# 1302    4    2.20            0    0  123.834341  Other Intel Processor   500
#
#       SSD Gpu brand                  os
# 0     128     Intel               MacOs
# 1       0     Intel               MacOs
# 2     256     Intel  Others/No OS/Linux
# 3     512       AMD               MacOs
# 4     256     Intel               MacOs
# ...   ...       ...                 ...
# 1298  128     Intel             Windows
# 1299  512     Intel             Windows
# 1300    0     Intel             Windows
# 1301    0       AMD             Windows
# 1302    0     Intel             Windows
#
# [1302 rows x 13 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName                           ScreenResolution  \
# 183   Toshiba            Notebook                                   1366x768
# 1141      MSI              Gaming                          Full HD 1920x1080
# 1049     Asus             Netbook                                   1366x768
# 1020     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 878      Dell            Notebook                          Full HD 1920x1080
# ...       ...                 ...                                        ...
# 466      Acer            Notebook                                   1366x768
# 299      Asus           Ultrabook                          Full HD 1920x1080
# 493      Acer            Notebook                                   1366x768
# 527    Lenovo            Notebook                                   1366x768
# 1193    Apple           Ultrabook         IPS Panel Retina Display 2304x1440
#
#       Ram  Weight  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 183     8    2.00            0    0  123.834341          Intel Core i5     0
# 1141    8    2.40            0    0  174.057054          Intel Core i7  1000
# 1049    4    1.20            0    0  166.535838  Other Intel Processor     0
# 1020    4    2.08            1    1  174.057054          Intel Core i3  1000
# 878     4    2.18            0    0  174.057054          Intel Core i5  1000
# ...   ...     ...          ...  ...         ...                    ...   ...
# 466     4    2.20            0    0  123.834341          Intel Core i3   500
# 299    16    1.63            0    0  174.057054          Intel Core i7     0
# 493     8    2.20            0    0  123.834341          AMD Processor  1000
# 527     8    2.20            0    0  123.834341          Intel Core i3  2000
# 1193    8    0.92            0    1  271.529004  Other Intel Processor     0
#
#       SSD Gpu brand                  os
# 183   128     Intel             Windows
# 1141  128    Nvidia             Windows
# 1049    0     Intel  Others/No OS/Linux
# 1020    0     Intel             Windows
# 878   128    Nvidia             Windows
# ...   ...       ...                 ...
# 466     0    Nvidia             Windows
# 299   512    Nvidia             Windows
# 493     0       AMD             Windows
# 527     0    Nvidia  Others/No OS/Linux
# 1193    0     Intel  Others/No OS/Linux
#
# [1106 rows x 13 columns]

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

X = df.drop("Price", axis=1)
y = pd.to_numeric(df["Price"], errors="coerce")

mask = y.notna()
X = X[mask]
y = y[mask].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, random_state=2
)

cat_cols = X_train.select_dtypes(include="object").columns
num_cols = X_train.select_dtypes(exclude="object").columns

# ---------------- PREPROCESS ----------------
numeric_transformer = SimpleImputer(strategy="median")

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(
        drop="first",
        handle_unknown="ignore",
        sparse_output=False
    ))
])

step1 = preprocessor = ColumnTransformer([
    ("num", numeric_transformer, num_cols),
    ("cat", categorical_transformer, cat_cols)
])


# ---------------- MODEL ----------------
step2 = RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)


pipe = Pipeline([
    ('preprocess', step1),
    ('model', step2)
])

# ---------------- TRAIN ----------------
pipe.fit(X_train, np.log1p(y_train))

#---------------- PREDICT ----------------
y_pred = np.expm1(pipe.predict(X_test))

# ---------------- EVALUATE ----------------
print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.8195952525426071
# MAE: 8931.937714734162
# C:\Users\supri\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_encoders.py:261: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import cross_val_score

cv_r2 = cross_val_score(
    pipe, X_train, np.log1p(y_train),
    cv=5, scoring="r2"
)

print("CV R2 Mean:", cv_r2.mean())
# Out:
# C:\Users\supri\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_encoders.py:261: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)
# CV R2 Mean: 0.8693475486533888
# C:\Users\supri\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_encoders.py:261: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)

# %%
relative_mae = mean_absolute_error(
    y_test / y_test.mean(),
    y_pred / y_test.mean()
)

print("Relative MAE:", relative_mae)
# Out:
# Relative MAE: 0.15598807416031113

# %%
X
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
#       Ram  Weight  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 0       8    1.37            0    1  272.209528          Intel Core i5     0
# 1       8    1.34            0    0  153.117859          Intel Core i5     0
# 2       8    1.86            0    0  174.057054          Intel Core i5     0
# 3      16    1.83            0    1  264.476303          Intel Core i7     0
# 4       8    1.37            0    1  272.209528          Intel Core i5     0
# ...   ...     ...          ...  ...         ...                    ...   ...
# 1298    4    1.80            1    1  193.949289          Intel Core i7     0
# 1299   16    1.30            1    1  340.261910          Intel Core i7     0
# 1300    2    1.50            0    0  137.986838  Other Intel Processor     0
# 1301    6    2.19            0    0  123.834341          Intel Core i7  1000
# 1302    4    2.20            0    0  123.834341  Other Intel Processor   500
#
#       SSD Gpu brand                  os
# 0     128     Intel               MacOs
# 1       0     Intel               MacOs
# 2     256     Intel  Others/No OS/Linux
# 3     512       AMD               MacOs
# 4     256     Intel               MacOs
# ...   ...       ...                 ...
# 1298  128     Intel             Windows
# 1299  512     Intel             Windows
# 1300    0     Intel             Windows
# 1301    0       AMD             Windows
# 1302    0     Intel             Windows
#
# [1302 rows x 13 columns]

# %%
y
# Out:
# array([71378.6832, 47895.5232, 30636.    , ..., 12201.12  , 40705.92  ,
#        19660.32  ], shape=(1302,))

# %%
X_test
# Out:
#      Company            TypeName  \
# 248       HP            Notebook
# 555     Asus            Notebook
# 1251      HP            Notebook
# 547   Lenovo            Notebook
# 885       HP  2 in 1 Convertible
# ...      ...                 ...
# 1129      HP              Gaming
# 172   Lenovo            Notebook
# 322     Asus            Notebook
# 996       HP           Ultrabook
# 470       HP  2 in 1 Convertible
#
#                                    ScreenResolution  Ram  Weight  Touchscreen  \
# 248                     IPS Panel Full HD 1920x1080    4    1.49            0
# 555                                        1366x768    4    2.00            0
# 1251                                       1366x768    4    1.86            0
# 547                               Full HD 1920x1080    4    2.15            0
# 885                 Full HD / Touchscreen 1920x1080    4    1.28            1
# ...                                             ...  ...     ...          ...
# 1129                    IPS Panel Full HD 1920x1080    8    3.35            0
# 172                                        1366x768    4    2.20            0
# 322                               Full HD 1920x1080    8    2.00            0
# 996       IPS Panel Full HD / Touchscreen 1920x1080    8    1.11            1
# 470   IPS Panel 4K Ultra HD / Touchscreen 3840x2160    8    1.29            1
#
#       Ips         ppi              Cpu brand   HDD  SSD Gpu brand  \
# 248     1  204.157146          Intel Core i5   500    0     Intel
# 555     0  123.834341  Other Intel Processor   500    0     Intel
# 1251    0  123.834341          AMD Processor   500    0       AMD
# 547     0  174.057054          Intel Core i5  1000    0     Intel
# 885     0  204.157146          Intel Core i5     0  256     Intel
# ...   ...         ...                    ...   ...  ...       ...
# 1129    1  156.953181          Intel Core i5  1000  128    Nvidia
# 172     0  123.834341          AMD Processor   500    0       AMD
# 322     0  193.949289          Intel Core i7     0  256     Intel
# 996     1  204.157146          Intel Core i7     0  256     Intel
# 470     1  408.314292          Intel Core i7     0  512     Intel
#
#                       os
# 248              Windows
# 555   Others/No OS/Linux
# 1251             Windows
# 547   Others/No OS/Linux
# 885              Windows
# ...                  ...
# 1129             Windows
# 172   Others/No OS/Linux
# 322              Windows
# 996              Windows
# 470              Windows
#
# [196 rows x 13 columns]

# %%
X_train
# Out:
#       Company            TypeName                           ScreenResolution  \
# 183   Toshiba            Notebook                                   1366x768
# 1141      MSI              Gaming                          Full HD 1920x1080
# 1049     Asus             Netbook                                   1366x768
# 1020     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 878      Dell            Notebook                          Full HD 1920x1080
# ...       ...                 ...                                        ...
# 466      Acer            Notebook                                   1366x768
# 299      Asus           Ultrabook                          Full HD 1920x1080
# 493      Acer            Notebook                                   1366x768
# 527    Lenovo            Notebook                                   1366x768
# 1193    Apple           Ultrabook         IPS Panel Retina Display 2304x1440
#
#       Ram  Weight  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 183     8    2.00            0    0  123.834341          Intel Core i5     0
# 1141    8    2.40            0    0  174.057054          Intel Core i7  1000
# 1049    4    1.20            0    0  166.535838  Other Intel Processor     0
# 1020    4    2.08            1    1  174.057054          Intel Core i3  1000
# 878     4    2.18            0    0  174.057054          Intel Core i5  1000
# ...   ...     ...          ...  ...         ...                    ...   ...
# 466     4    2.20            0    0  123.834341          Intel Core i3   500
# 299    16    1.63            0    0  174.057054          Intel Core i7     0
# 493     8    2.20            0    0  123.834341          AMD Processor  1000
# 527     8    2.20            0    0  123.834341          Intel Core i3  2000
# 1193    8    0.92            0    1  271.529004  Other Intel Processor     0
#
#       SSD Gpu brand                  os
# 183   128     Intel             Windows
# 1141  128    Nvidia             Windows
# 1049    0     Intel  Others/No OS/Linux
# 1020    0     Intel             Windows
# 878   128    Nvidia             Windows
# ...   ...       ...                 ...
# 466     0    Nvidia             Windows
# 299   512    Nvidia             Windows
# 493     0       AMD             Windows
# 527     0    Nvidia  Others/No OS/Linux
# 1193    0     Intel  Others/No OS/Linux
#
# [1106 rows x 13 columns]

# %%
y_train
# Out:
# array([42251.04 , 60888.384, 15339.312, ..., 30849.12 , 24455.52 ,
#        61964.64 ], shape=(1106,))

# %%
X_test
# Out:
#      Company            TypeName  \
# 248       HP            Notebook
# 555     Asus            Notebook
# 1251      HP            Notebook
# 547   Lenovo            Notebook
# 885       HP  2 in 1 Convertible
# ...      ...                 ...
# 1129      HP              Gaming
# 172   Lenovo            Notebook
# 322     Asus            Notebook
# 996       HP           Ultrabook
# 470       HP  2 in 1 Convertible
#
#                                    ScreenResolution  Ram  Weight  Touchscreen  \
# 248                     IPS Panel Full HD 1920x1080    4    1.49            0
# 555                                        1366x768    4    2.00            0
# 1251                                       1366x768    4    1.86            0
# 547                               Full HD 1920x1080    4    2.15            0
# 885                 Full HD / Touchscreen 1920x1080    4    1.28            1
# ...                                             ...  ...     ...          ...
# 1129                    IPS Panel Full HD 1920x1080    8    3.35            0
# 172                                        1366x768    4    2.20            0
# 322                               Full HD 1920x1080    8    2.00            0
# 996       IPS Panel Full HD / Touchscreen 1920x1080    8    1.11            1
# 470   IPS Panel 4K Ultra HD / Touchscreen 3840x2160    8    1.29            1
#
#       Ips         ppi              Cpu brand   HDD  SSD Gpu brand  \
# 248     1  204.157146          Intel Core i5   500    0     Intel
# 555     0  123.834341  Other Intel Processor   500    0     Intel
# 1251    0  123.834341          AMD Processor   500    0       AMD
# 547     0  174.057054          Intel Core i5  1000    0     Intel
# 885     0  204.157146          Intel Core i5     0  256     Intel
# ...   ...         ...                    ...   ...  ...       ...
# 1129    1  156.953181          Intel Core i5  1000  128    Nvidia
# 172     0  123.834341          AMD Processor   500    0       AMD
# 322     0  193.949289          Intel Core i7     0  256     Intel
# 996     1  204.157146          Intel Core i7     0  256     Intel
# 470     1  408.314292          Intel Core i7     0  512     Intel
#
#                       os
# 248              Windows
# 555   Others/No OS/Linux
# 1251             Windows
# 547   Others/No OS/Linux
# 885              Windows
# ...                  ...
# 1129             Windows
# 172   Others/No OS/Linux
# 322              Windows
# 996              Windows
# 470              Windows
#
# [196 rows x 13 columns]

# %%
y_test
# Out:
# array([ 35964.    ,  11934.72  ,  21258.72  ,  24634.008 ,  95850.72  ,
#         99047.52  ,  23922.72  ,  29783.52  ,  63499.104 ,  14492.16  ,
#         99900.    ,  47365.92  ,  83170.08  ,  45664.6896,  98834.4   ,
#         47898.72  ,  72673.92  ,  11135.52  , 111593.8944,  95850.72  ,
#        104370.192 , 107305.92  ,  42570.72  ,  54665.28  ,  29783.52  ,
#         98514.72  ,  52054.56  ,  18594.72  ,  68184.0144,  53733.9456,
#         92121.12  ,  14811.3072,  46833.12  ,  53226.72  ,  67772.16  ,
#         35644.32  ,  97449.12  ,  63349.92  , 107892.    ,  85194.72  ,
#        101178.72  ,  99793.44  ,  14418.6336,  26640.    ,  26586.72  ,
#         19441.872 ,  45074.88  ,  81731.52  ,  94731.84  ,  71661.6   ,
#        133146.72  , 120831.5808,  20725.92  ,  17582.4   ,  33513.12  ,
#         60978.96  ,  20193.12  , 100965.6   ,  21258.1872,  34578.72  ,
#         52693.92  ,  66546.72  ,  10224.432 ,  69210.72  ,  59461.5456,
#         25840.8   ,  19660.32  ,  79813.44  ,  45767.52  ,  23922.72  ,
#         55677.6   ,  44542.08  ,  39164.5296,  31914.72  ,  69210.72  ,
#         69103.6272,  71341.92  , 141884.64  ,  79866.72  ,  38378.6496,
#         63349.92  ,  72354.24  ,  53173.44  ,  30103.2   , 165168.    ,
#         52054.56  ,  46833.12  , 101178.72  ,  26053.92  ,  53226.72  ,
#         48058.56  ,  31381.92  ,  45074.88  ,  95850.72  ,  34632.    ,
#         15397.92  ,  40980.312 ,  32127.84  ,  16463.52  , 126273.6   ,
#         28504.8   ,  63722.88  ,  24808.2336, 113752.8   ,  44701.92  ,
#         79215.1056,  74538.72  ,  52693.92  ,  61735.536 ,  23655.7872,
#         42943.68  ,  45768.0528,  30849.12  ,  80133.12  ,  24455.52  ,
#         40173.12  ,  13266.72  ,  70809.12  ,  40705.92  ,  45234.72  ,
#         34472.16  ,  85672.1088,  52214.4   ,  39160.8   ,  39906.72  ,
#         63882.72  ,  39267.36  ,  16463.52  , 130003.2   ,  89510.4   ,
#         33513.12  ,  69210.72  ,  27899.0064,  58554.72  ,  62231.04  ,
#         29250.72  ,  64948.32  ,  71847.0144,  69210.72  ,  84768.48  ,
#         12201.12  ,  13266.72  ,  47898.72  ,  28717.92  ,  39533.76  ,
#        123876.    ,  36496.8   ,  20193.12  ,  80908.344 ,  41025.0672,
#        160520.3856,  90522.72  ,  61218.72  , 101391.84  ,  59513.2272,
#         49656.96  ,  50882.4   , 139860.    ,  66546.72  ,  79866.72  ,
#         12201.12  ,  21258.72  ,  39373.92  ,  35004.96  ,  64308.96  ,
#         49976.64  , 130482.72  ,  26586.72  ,  98514.72  ,  67559.04  ,
#         26533.44  ,  42570.72  ,  25521.12  ,  50669.28  ,  52161.12  ,
#         60153.12  , 124568.64  , 133146.72  ,  58021.92  ,  25515.2592,
#         39960.    ,  49816.8   ,  64755.4464,  38841.12  ,  23373.4032,
#         35111.52  ,  42943.1472,  75924.    ,  61751.52  ,  29250.72  ,
#         18594.72  ,  60153.12  ,  16463.52  ,  58288.32  ,  71874.72  ,
#        106506.72  ])

# %%
import pickle

# %%
df
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
#       Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0       8    1.37   71378.6832            0    1  272.209528
# 1       8    1.34   47895.5232            0    0  153.117859
# 2       8    1.86   30636.0000            0    0  174.057054
# 3      16    1.83  135195.3360            0    1  264.476303
# 4       8    1.37   96095.8080            0    1  272.209528
# ...   ...     ...          ...          ...  ...         ...
# 1298    4    1.80   33992.6400            1    1  193.949289
# 1299   16    1.30   79866.7200            1    1  340.261910
# 1300    2    1.50   12201.1200            0    0  137.986838
# 1301    6    2.19   40705.9200            0    0  123.834341
# 1302    4    2.20   19660.3200            0    0  123.834341
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 0             Intel Core i5     0  128     Intel               MacOs
# 1             Intel Core i5     0    0     Intel               MacOs
# 2             Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3             Intel Core i7     0  512       AMD               MacOs
# 4             Intel Core i5     0  256     Intel               MacOs
# ...                     ...   ...  ...       ...                 ...
# 1298          Intel Core i7     0  128     Intel             Windows
# 1299          Intel Core i7     0  512     Intel             Windows
# 1300  Other Intel Processor     0    0     Intel             Windows
# 1301          Intel Core i7  1000    0       AMD             Windows
# 1302  Other Intel Processor   500    0     Intel             Windows
#
# [1302 rows x 14 columns]

# %%
X_train
# Out:
#       Company            TypeName                           ScreenResolution  \
# 183   Toshiba            Notebook                                   1366x768
# 1141      MSI              Gaming                          Full HD 1920x1080
# 1049     Asus             Netbook                                   1366x768
# 1020     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 878      Dell            Notebook                          Full HD 1920x1080
# ...       ...                 ...                                        ...
# 466      Acer            Notebook                                   1366x768
# 299      Asus           Ultrabook                          Full HD 1920x1080
# 493      Acer            Notebook                                   1366x768
# 527    Lenovo            Notebook                                   1366x768
# 1193    Apple           Ultrabook         IPS Panel Retina Display 2304x1440
#
#       Ram  Weight  Touchscreen  Ips         ppi              Cpu brand   HDD  \
# 183     8    2.00            0    0  123.834341          Intel Core i5     0
# 1141    8    2.40            0    0  174.057054          Intel Core i7  1000
# 1049    4    1.20            0    0  166.535838  Other Intel Processor     0
# 1020    4    2.08            1    1  174.057054          Intel Core i3  1000
# 878     4    2.18            0    0  174.057054          Intel Core i5  1000
# ...   ...     ...          ...  ...         ...                    ...   ...
# 466     4    2.20            0    0  123.834341          Intel Core i3   500
# 299    16    1.63            0    0  174.057054          Intel Core i7     0
# 493     8    2.20            0    0  123.834341          AMD Processor  1000
# 527     8    2.20            0    0  123.834341          Intel Core i3  2000
# 1193    8    0.92            0    1  271.529004  Other Intel Processor     0
#
#       SSD Gpu brand                  os
# 183   128     Intel             Windows
# 1141  128    Nvidia             Windows
# 1049    0     Intel  Others/No OS/Linux
# 1020    0     Intel             Windows
# 878   128    Nvidia             Windows
# ...   ...       ...                 ...
# 466     0    Nvidia             Windows
# 299   512    Nvidia             Windows
# 493     0       AMD             Windows
# 527     0    Nvidia  Others/No OS/Linux
# 1193    0     Intel  Others/No OS/Linux
#
# [1106 rows x 13 columns]

# %%
import pickle 
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
#       Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0       8    1.37   71378.6832            0    1  272.209528
# 1       8    1.34   47895.5232            0    0  153.117859
# 2       8    1.86   30636.0000            0    0  174.057054
# 3      16    1.83  135195.3360            0    1  264.476303
# 4       8    1.37   96095.8080            0    1  272.209528
# ...   ...     ...          ...          ...  ...         ...
# 1298    4    1.80   33992.6400            1    1  193.949289
# 1299   16    1.30   79866.7200            1    1  340.261910
# 1300    2    1.50   12201.1200            0    0  137.986838
# 1301    6    2.19   40705.9200            0    0  123.834341
# 1302    4    2.20   19660.3200            0    0  123.834341
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 0             Intel Core i5     0  128     Intel               MacOs
# 1             Intel Core i5     0    0     Intel               MacOs
# 2             Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3             Intel Core i7     0  512       AMD               MacOs
# 4             Intel Core i5     0  256     Intel               MacOs
# ...                     ...   ...  ...       ...                 ...
# 1298          Intel Core i7     0  128     Intel             Windows
# 1299          Intel Core i7     0  512     Intel             Windows
# 1300  Other Intel Processor     0    0     Intel             Windows
# 1301          Intel Core i7  1000    0       AMD             Windows
# 1302  Other Intel Processor   500    0     Intel             Windows
#
# [1302 rows x 14 columns]

# %%
df.value_counts()
# Out:
# Company  TypeName            ScreenResolution                 Ram  Weight  Price        Touchscreen  Ips  ppi         Cpu brand              HDD   SSD  Gpu brand  os
# Asus     Notebook            1366x768                         4    2.20    19660.3200   0            0    123.834341  Other Intel Processor  500   0    Intel      Windows               4
# Dell     Notebook            1366x768                         8    2.30    42943.1472   0            0    123.834341  Intel Core i7          1000  0    AMD        Others/No OS/Linux    3
#                                                               2    2.20    20193.1200   0            0    123.834341  Other Intel Processor  500   0    Intel      Windows               3
# HP       Netbook             1366x768                         2    1.17    11135.5200   0            0    166.535838  Other Intel Processor  0     0    Intel      Windows               3
# Asus     Notebook            1366x768                         4    2.20    38378.6496   0            0    123.834341  Intel Core i7          500   0    Nvidia     Windows               3
#                                                                                                                                                                                         ..
# Toshiba  Notebook            IPS Panel Full HD 1920x1080      16   2.40    105228.0000  0            1    174.057054  Intel Core i7          0     256  Nvidia     Windows               1
#          Ultrabook           1366x768                         4    1.25    58075.2000   0            0    137.986838  Intel Core i5          0     128  Intel      Windows               1
#                                                               8    1.20    58341.6000   0            0    145.249303  Intel Core i5          0     256  Intel      Windows               1
#                              Full HD / Touchscreen 1920x1080  8    1.10    95371.2000   1            0    217.223203  Intel Core i7          0     512  Intel      Windows               1
# Acer     2 in 1 Convertible  IPS Panel Touchscreen 1366x768   4    1.25    20725.9200   1            1    166.535838  Other Intel Processor  0     0    Intel      Others/No OS/Linux    1
# Name: count, Length: 1272, dtype: int64
